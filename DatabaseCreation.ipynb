# %% [markdown]
# # OLAP Database of birds in US National Parks

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ----
# &nbsp;
# ### Verifying Integrity of Dataset

# %%
birds = pd.read_pickle('DATA/birds.pkl')
print(f"Shape: {birds.shape}")
print(f"Data Types:\n\n{birds.dtypes}\n")
# Out:
# Shape: (14451, 16)
# Data Types:
#
# species_id               object
# park_code                object
# park_name                object
# order                    object
# family                   object
# scientific_name          object
# common_names             object
# raptor_group             object
# record_status          category
# occurrence             category
# nativeness             category
# abundance              category
# seasonality              object
# conservation_status    category
# is_protected               bool
# is_raptor                  bool
# dtype: object

# %%
print(f"Unique values:\n\n{birds.nunique()}")
# Out:
# Unique values:
#
# species_id             14451
# park_code                 56
# park_name                 56
# order                     24
# family                    86
# scientific_name         1177
# common_names            1162
# raptor_group              12
# record_status              2
# occurrence                 5
# nativeness                 3
# abundance                  6
# seasonality                7
# conservation_status        7
# is_protected               2
# is_raptor                  2
# dtype: int64

# %%
# Count the number of NaN values in each column
nan_counts_per_column = birds.isna().sum()
print(f"NaN counts:\n\n{nan_counts_per_column}")
# Out:
# NaN counts:
#
# species_id             0
# park_code              0
# park_name              0
# order                  0
# family                 0
# scientific_name        0
# common_names           0
# raptor_group           0
# record_status          0
# occurrence             0
# nativeness             0
# abundance              0
# seasonality            0
# conservation_status    0
# is_protected           0
# is_raptor              0
# dtype: int64

# %% [markdown]
# ----
# &nbsp;
# ### Extracting Species Data

# %%
birds.head()
# Out:
#    species_id park_code park_name            order        family  \
# 55  ACAD-1055      ACAD    Acadia  Accipitriformes  Accipitridae
# 56  ACAD-1056      ACAD    Acadia  Accipitriformes  Accipitridae
# 57  ACAD-1057      ACAD    Acadia  Accipitriformes  Accipitridae
# 58  ACAD-1058      ACAD    Acadia  Accipitriformes  Accipitridae
# 59  ACAD-1059      ACAD    Acadia  Accipitriformes  Accipitridae
#
#        scientific_name        common_names raptor_group record_status  \
# 55  Accipiter cooperii       Cooper's Hawk         Hawk      Approved
# 56  Accipiter gentilis    Northern Goshawk         Hawk      Approved
# 57  Accipiter striatus  Sharp-Shinned Hawk         Hawk      Approved
# 58   Aquila chrysaetos        Golden Eagle        Eagle      Approved
# 59   Buteo jamaicensis     Red-Tailed Hawk         Hawk      Approved
#
#    occurrence nativeness   abundance seasonality conservation_status  \
# 55    Present     Native    Uncommon     Unknown  Species of Concern
# 56    Present     Native    Uncommon     Breeder       Least Concern
# 57    Present     Native      Common     Breeder  Species of Concern
# 58    Present     Native  Occasional     Vagrant  Species of Concern
# 59    Present     Native      Common     Breeder       Least Concern
#
#     is_protected  is_raptor
# 55          True       True
# 56         False       True
# 57          True       True
# 58          True       True
# 59         False       True

# %%
# We create a subset DataFrame of species information only
species = birds[['order', 'family', 'scientific_name', 'common_names', 'raptor_group']]
species.head()
# Out:
#               order        family     scientific_name        common_names  \
# 55  Accipitriformes  Accipitridae  Accipiter cooperii       Cooper's Hawk
# 56  Accipitriformes  Accipitridae  Accipiter gentilis    Northern Goshawk
# 57  Accipitriformes  Accipitridae  Accipiter striatus  Sharp-Shinned Hawk
# 58  Accipitriformes  Accipitridae   Aquila chrysaetos        Golden Eagle
# 59  Accipitriformes  Accipitridae   Buteo jamaicensis     Red-Tailed Hawk
#
#    raptor_group
# 55         Hawk
# 56         Hawk
# 57         Hawk
# 58        Eagle
# 59         Hawk

# %%
species = species.rename(columns={'common_names': 'common_name'})
species = species.drop_duplicates()
species = species.sort_values(by='scientific_name')

print(f"Unique records: {species.shape[0]}")
species.head()
# Out:
# Unique records: 1179
#                  order        family                  scientific_name  \
# 55     Accipitriformes  Accipitridae               Accipiter cooperii
# 56     Accipitriformes  Accipitridae               Accipiter gentilis
# 78390  Accipitriformes  Accipitridae  Accipiter gentilis atricapillus
# 78391  Accipitriformes  Accipitridae        Accipiter gentilis laingi
# 57     Accipitriformes  Accipitridae               Accipiter striatus
#
#                                       common_name raptor_group
# 55                                  Cooper's Hawk         Hawk
# 56                               Northern Goshawk         Hawk
# 78390  Northern Goshawk (atricapillus subspecies)         Hawk
# 78391        Northern Goshawk (laingi subspecies)         Hawk
# 57                             Sharp-Shinned Hawk         Hawk

# %%
unique_sci_names = species['scientific_name'].nunique()
print(f"Unique scientific names: {unique_sci_names}")
# Out:
# Unique scientific names: 1177

# %%
# Group by scientific name and count occurrences
duplicates = species.groupby('scientific_name').size()
duplicates = duplicates[duplicates > 1]

print(f"Duplicated scientific names:\n{duplicates}")
# Out:
# Duplicated scientific names:
# scientific_name
# Phylloscopus borealis    2
# Polioptila caerulea      2
# dtype: int64

# %%
# List of duplicated scientific names
duplicated_sci_names = ['Phylloscopus borealis', 'Polioptila caerulea']
duplicated_records = species[species['scientific_name'].isin(duplicated_sci_names)]
duplicated_records
# Out:
#                order          family        scientific_name  \
# 24944  Passeriformes    Muscicapidae  Phylloscopus borealis
# 24956  Passeriformes  Phylloscopidae  Phylloscopus borealis
# 2928   Passeriformes      Certhiidae    Polioptila caerulea
# 326    Passeriformes   Polioptilidae    Polioptila caerulea
#
#                  common_name raptor_group
# 24944         Arctic Warbler         None
# 24956         Arctic Warbler         None
# 2928   Blue-Gray Gnatcatcher         None
# 326    Blue-Gray Gnatcatcher         None

# %%
# Correct families for the scientific names
correct_families = {
    'Phylloscopus borealis': 'Phylloscopidae',  # Assuming this is the correct family
    'Polioptila caerulea': 'Polioptilidae'     # Assuming this is the correct family
}

# Update the family in the birds DataFrame
for sci_name, correct_family in correct_families.items():
    birds.loc[birds['scientific_name'] == sci_name, 'family'] = correct_family

# Update the family in the species DataFrame
for sci_name, correct_family in correct_families.items():
    species.loc[species['scientific_name'] == sci_name, 'family'] = correct_family

# %%
species = species.drop_duplicates()
species = species.sort_values(by='scientific_name')
species = species.reset_index(drop=True)

print(f"Unique records: {species.shape[0]}")
species.head(10)
# Out:
# Unique records: 1177
#               order         family                  scientific_name  \
# 0   Accipitriformes   Accipitridae               Accipiter cooperii
# 1   Accipitriformes   Accipitridae               Accipiter gentilis
# 2   Accipitriformes   Accipitridae  Accipiter gentilis atricapillus
# 3   Accipitriformes   Accipitridae        Accipiter gentilis laingi
# 4   Accipitriformes   Accipitridae               Accipiter striatus
# 5   Accipitriformes   Accipitridae         Accipiter striatus velox
# 6     Passeriformes      Sturnidae             Acridotheres tristis
# 7   Charadriiformes   Scolopacidae               Actitis hypoleucos
# 8   Charadriiformes   Scolopacidae               Actitis macularius
# 9  Podicipediformes  Podicipedidae             Aechmophorus clarkii
#
#                                   common_name raptor_group
# 0                               Cooper's Hawk         Hawk
# 1                            Northern Goshawk         Hawk
# 2  Northern Goshawk (atricapillus subspecies)         Hawk
# 3        Northern Goshawk (laingi subspecies)         Hawk
# 4                          Sharp-Shinned Hawk         Hawk
# 5       Sharp-Shinned Hawk (velox subspecies)         Hawk
# 6                                 Common Myna         None
# 7                            Common Sandpiper         None
# 8                           Spotted Sandpiper         None
# 9                               Clark's Grebe         None

# %%
# Create a species_id column with leading zeros (e.g., 0001, 0002, ...)
species['species_id'] = species.reset_index().index + 1  # Start with 1
species['species_id'] = species['species_id'].apply(lambda x: f"{x:04d}")  # Format with leading zeros for 4 digits

# Move 'species_id' to be the first column
species = species[['species_id'] + [col for col in species.columns if col != 'species_id']]
species.head()
# Out:
#   species_id            order        family                  scientific_name  \
# 0       0001  Accipitriformes  Accipitridae               Accipiter cooperii
# 1       0002  Accipitriformes  Accipitridae               Accipiter gentilis
# 2       0003  Accipitriformes  Accipitridae  Accipiter gentilis atricapillus
# 3       0004  Accipitriformes  Accipitridae        Accipiter gentilis laingi
# 4       0005  Accipitriformes  Accipitridae               Accipiter striatus
#
#                                   common_name raptor_group
# 0                               Cooper's Hawk         Hawk
# 1                            Northern Goshawk         Hawk
# 2  Northern Goshawk (atricapillus subspecies)         Hawk
# 3        Northern Goshawk (laingi subspecies)         Hawk
# 4                          Sharp-Shinned Hawk         Hawk

# %%
species.tail()
# Out:
#      species_id          order        family  \
# 1172       1173  Passeriformes   Emberizidae
# 1173       1174  Passeriformes   Emberizidae
# 1174       1175  Passeriformes   Emberizidae
# 1175       1176  Passeriformes   Emberizidae
# 1176       1177  Passeriformes  Zosteropidae
#
#                         scientific_name  \
# 1172  Zonotrichia leucophrys leucophrys
# 1173    Zonotrichia leucophrys oriantha
# 1174  Zonotrichia leucophrys pugetensis
# 1175                Zonotrichia querula
# 1176                Zosterops japonicus
#
#                                         common_name raptor_group
# 1172  White-Crowned Sparrow (leucophrys subspecies)         None
# 1173    White-Crowned Sparrow (Mountain Subspecies)         None
# 1174  White-Crowned Sparrow (pugetensis subspecies)         None
# 1175                               Harris's Sparrow         None
# 1176                             Japanese White-Eye         None

# %% [markdown]
# ----
# &nbsp;
# ### Matching species data with the park records
